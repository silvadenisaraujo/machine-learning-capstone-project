# %%
import bq_helper
from bq_helper import BigQueryHelper

ghnp = bq_helper.BigQueryHelper(active_project="bigquery-public-data",
                                   dataset_name="world_bank_health_population")

# %%
bq_assistant = BigQueryHelper("bigquery-public-data", "world_bank_health_population")
bq_assistant.list_tables()
# Out:
# ['country_series_definitions',
#  'country_summary',
#  'health_nutrition_population',
#  'series_summary',
#  'series_times']

# %%
bq_assistant.head("health_nutrition_population", num_rows=30)
# Out:
#                                     country_name country_code  \
# 0                                     Uzbekistan          UZB
# 1                                          Nepal          NPL
# 2   Least developed countries: UN classification          LDC
# 3                                         Mexico          MEX
# 4                                           Cuba          CUB
# 5                       Central African Republic          CAF
# 6                                        Lebanon          LBN
# 7                                     Azerbaijan          AZE
# 8                                Slovak Republic          SVK
# 9                                   South Africa          ZAF
# 10                                       Namibia          NAM
# 11                                   El Salvador          SLV
# 12    East Asia & Pacific (IDA & IBRD countries)          TEA
# 13                                         Samoa          WSM
# 14                Central Europe and the Baltics          CEB
# 15                                      Pakistan          PAK
# 16                                      Bulgaria          BGR
# 17                                          Guam          GUM
# 18                                         Samoa          WSM
# 19                                   Timor-Leste          TLS
# 20                               Solomon Islands          SLB
# 21                                       Burundi          BDI
# 22                                    Montenegro          MNE
# 23                                       Myanmar          MMR
# 24                              Congo, Dem. Rep.          COD
# 25                                       Vanuatu          VUT
# 26                           Upper middle income          UMC
# 27                                        Guinea          GIN
# 28                               Kyrgyz Republic          KGZ
# 29                                          Chad          TCD
#
#                                     indicator_name     indicator_code  year  \
# 0       Unemployment, male (% of male labor force)  SL.UEM.TOTL.MA.ZS  2018
# 1       Unemployment, male (% of male labor force)  SL.UEM.TOTL.MA.ZS  2018
# 2   Unemployment, female (% of female labor force)  SL.UEM.TOTL.FE.ZS  2018
# 3       Unemployment, male (% of male labor force)  SL.UEM.TOTL.MA.ZS  2018
# 4       Unemployment, male (% of male labor force)  SL.UEM.TOTL.MA.ZS  2018
# 5   Unemployment, female (% of female labor force)  SL.UEM.TOTL.FE.ZS  2018
# 6                               Labor force, total     SL.TLF.TOTL.IN  2018
# 7       Unemployment, male (% of male labor force)  SL.UEM.TOTL.MA.ZS  2018
# 8     Unemployment, total (% of total labor force)     SL.UEM.TOTL.ZS  2018
# 9       Unemployment, male (% of male labor force)  SL.UEM.TOTL.MA.ZS  2018
# 10    Labor force, female (% of total labor force)  SL.TLF.TOTL.FE.ZS  2018
# 11      Unemployment, male (% of male labor force)  SL.UEM.TOTL.MA.ZS  2018
# 12    Labor force, female (% of total labor force)  SL.TLF.TOTL.FE.ZS  2018
# 13    Unemployment, total (% of total labor force)     SL.UEM.TOTL.ZS  2018
# 14    Unemployment, total (% of total labor force)     SL.UEM.TOTL.ZS  2018
# 15  Unemployment, female (% of female labor force)  SL.UEM.TOTL.FE.ZS  2018
# 16                              Labor force, total     SL.TLF.TOTL.IN  2018
# 17                              Labor force, total     SL.TLF.TOTL.IN  2018
# 18  Unemployment, female (% of female labor force)  SL.UEM.TOTL.FE.ZS  2018
# 19      Unemployment, male (% of male labor force)  SL.UEM.TOTL.MA.ZS  2018
# 20      Unemployment, male (% of male labor force)  SL.UEM.TOTL.MA.ZS  2018
# 21      Unemployment, male (% of male labor force)  SL.UEM.TOTL.MA.ZS  2018
# 22    Unemployment, total (% of total labor force)     SL.UEM.TOTL.ZS  2018
# 23    Labor force, female (% of total labor force)  SL.TLF.TOTL.FE.ZS  2018
# 24      Unemployment, male (% of male labor force)  SL.UEM.TOTL.MA.ZS  2018
# 25      Unemployment, male (% of male labor force)  SL.UEM.TOTL.MA.ZS  2018
# 26                              Labor force, total     SL.TLF.TOTL.IN  2018
# 27    Labor force, female (% of total labor force)  SL.TLF.TOTL.FE.ZS  2018
# 28  Unemployment, female (% of female labor force)  SL.UEM.TOTL.FE.ZS  2018
# 29  Unemployment, female (% of female labor force)  SL.UEM.TOTL.FE.ZS  2018
#
#            value
# 0   6.936000e+00
# 1   3.187000e+00
# 2   6.417805e+00
# 3   3.268000e+00
# 4   2.395000e+00
# 5   6.483000e+00
# 6   2.229303e+06
# 7   4.686000e+00
# 8   7.268000e+00
# 9   2.559000e+01
# 10  4.954466e+01
# 11  5.108000e+00
# 12  4.304005e+01
# 13  8.098000e+00
# 14  4.680785e+00
# 15  7.295000e+00
# 16  3.211189e+06
# 17  8.097200e+04
# 18  9.636000e+00
# 19  2.989000e+00
# 20  1.972000e+00
# 21  1.966000e+00
# 22  1.611600e+01
# 23  4.071705e+01
# 24  3.095000e+00
# 25  4.615000e+00
# 26  1.331493e+09
# 27  4.908887e+01
# 28  8.918000e+00
# 29  7.034000e+00

# %%
bq_assistant.head("health_nutrition_population", num_rows=30)
